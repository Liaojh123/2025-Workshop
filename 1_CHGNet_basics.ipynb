# %% [markdown]
# # Installation

# %%
pip install chgnet
# Out:
# Requirement already satisfied: chgnet in /usr/local/lib/python3.12/dist-packages (0.4.0)
# Requirement already satisfied: ase>=3.23.0 in /usr/local/lib/python3.12/dist-packages (from chgnet) (3.26.0)
# Requirement already satisfied: cython>=3 in /usr/local/lib/python3.12/dist-packages (from chgnet) (3.0.12)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from chgnet) (2.0.2)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.12/dist-packages (from chgnet) (7.352.0)
# Requirement already satisfied: pymatgen>=2024.9.10 in /usr/local/lib/python3.12/dist-packages (from chgnet) (2025.6.14)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from chgnet) (2.8.0+cu126)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from chgnet) (4.15.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from ase>=3.23.0->chgnet) (1.16.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.12/dist-packages (from ase>=3.23.0->chgnet) (3.10.0)
# Requirement already satisfied: bibtexparser>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (1.4.3)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (1.5.2)
# Requirement already satisfied: monty>=2025.1.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (2025.3.3)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (3.5)
# Requirement already satisfied: orjson<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (3.11.3)
# Requirement already satisfied: palettable>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (3.3.3)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (5.24.1)
# Requirement already satisfied: requests>=2.32 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (2.32.4)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (0.18.15)
# Requirement already satisfied: spglib>=2.5 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (2.6.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (1.13.3)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.9.10->chgnet) (3.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->chgnet) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from bibtexparser>=1.4.0->pymatgen>=2024.9.10->chgnet) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.4->ase>=3.23.0->chgnet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen>=2024.9.10->chgnet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen>=2024.9.10->chgnet) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->pymatgen>=2024.9.10->chgnet) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32->pymatgen>=2024.9.10->chgnet) (2025.8.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml>=0.17.0->pymatgen>=2024.9.10->chgnet) (0.2.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->pymatgen>=2024.9.10->chgnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->chgnet) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase>=3.23.0->chgnet) (1.17.0)

# %% [markdown]
# # Static Calculation (Predict energy, force, stress, magmom)

# %%
from chgnet.model.model import CHGNet

# Define Model

chgnet = CHGNet.load()

# Alternatively you can read your own model
# chgnet = CHGNet.from_file(model_path)
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu

# %%
from pymatgen.core import Structure

structure = Structure.from_file('/content/drive/MyDrive/LiCoO2.cif')

print(structure)
# Out:
# Full Formula (Li3 Co3 O6)
# Reduced Formula: LiCoO2
# abc   :   2.811257   2.811257  13.909456
# angles:  90.000000  90.000000 120.000000
# pbc   :       True       True       True
# Sites (12)
#   #  SP           a         b         c
# ---  ----  --------  --------  --------
#   0  Li    0         0         0
#   1  Li    0.666667  0.333333  0.333333
#   2  Li    0.333333  0.666667  0.666667
#   3  Co    0.333333  0.666667  0.166667
#   4  Co    0         0         0.5
#   5  Co    0.666667  0.333333  0.833333
#   6  O     0         0         0.240007
#   7  O     0.666667  0.333333  0.093327
#   8  O     0.666667  0.333333  0.57334
#   9  O     0.333333  0.666667  0.42666
#  10  O     0.333333  0.666667  0.906673
#  11  O     0         0         0.759993
# /usr/local/lib/python3.12/dist-packages/pymatgen/core/structure.py:3107: UserWarning:
#
# Issues encountered while parsing CIF: 18 fractional coordinates rounded to ideal values to avoid issues with finite precision.

# %%
prediction = chgnet.predict_structure(structure)

for key, unit in [
    ("energy", "eV/atom"),
    ("forces", "eV/A"),
    ("stress", "GPa"),
    ("magmom", "mu_B"),
]:
    print(f"CHGNet-predicted {key} ({unit}):\n{prediction[key[0]]}\n")
# Out:
# CHGNet-predicted energy (eV/atom):
# -6.360123634338379
#
# CHGNet-predicted forces (eV/A):
# [[-1.1920929e-07 -1.1557713e-06  6.9013331e-06]
#  [ 4.4703484e-08 -1.4901161e-07  2.8680079e-06]
#  [-8.9406967e-08  8.7742228e-07 -8.9313253e-06]
#  [ 2.9802322e-07  6.4005144e-07 -1.5412505e-05]
#  [ 1.0728836e-06  2.2917520e-06  3.0947849e-06]
#  [-1.1324883e-06 -1.7881393e-07  1.1634213e-05]
#  [-1.2218952e-06 -1.1120264e-06  5.6092423e-01]
#  [ 1.1771917e-06  1.6689301e-06 -5.6095028e-01]
#  [-2.0861626e-07 -1.2218952e-06  5.6092298e-01]
#  [-1.3411045e-06 -1.6149133e-06 -5.6092024e-01]
#  [ 1.1324883e-06 -2.2165477e-07  5.6094050e-01]
#  [ 4.4703484e-07  8.7544322e-08 -5.6091660e-01]]
#
# CHGNet-predicted stress (GPa):
# [[-1.0012475e+01  1.7253496e-05  2.1326255e-06]
#  [ 1.5662563e-05 -1.0012482e+01 -7.9371250e-07]
#  [ 1.5314703e-06 -1.7851001e-07 -9.6903973e+00]]
#
# CHGNet-predicted magmom (mu_B):
# [0.00392914 0.00392941 0.00392956 0.32530326 0.32530087 0.32529953
#  0.01235986 0.01236007 0.01235968 0.01235977 0.01235998 0.0123598 ]

# %%
print(prediction)
# Out:
# {'e': array(-6.3601236, dtype=float32), 'm': array([0.00392914, 0.00392941, 0.00392956, 0.32530326, 0.32530087,
#        0.32529953, 0.01235986, 0.01236007, 0.01235968, 0.01235977,
#        0.01235998, 0.0123598 ], dtype=float32), 's': array([[-1.0012475e+01,  1.7253496e-05,  2.1326255e-06],
#        [ 1.5662563e-05, -1.0012482e+01, -7.9371250e-07],
#        [ 1.5314703e-06, -1.7851001e-07, -9.6903973e+00]], dtype=float32), 'f': array([[-1.1920929e-07, -1.1557713e-06,  6.9013331e-06],
#        [ 4.4703484e-08, -1.4901161e-07,  2.8680079e-06],
#        [-8.9406967e-08,  8.7742228e-07, -8.9313253e-06],
#        [ 2.9802322e-07,  6.4005144e-07, -1.5412505e-05],
#        [ 1.0728836e-06,  2.2917520e-06,  3.0947849e-06],
#        [-1.1324883e-06, -1.7881393e-07,  1.1634213e-05],
#        [-1.2218952e-06, -1.1120264e-06,  5.6092423e-01],
#        [ 1.1771917e-06,  1.6689301e-06, -5.6095028e-01],
#        [-2.0861626e-07, -1.2218952e-06,  5.6092298e-01],
#        [-1.3411045e-06, -1.6149133e-06, -5.6092024e-01],
#        [ 1.1324883e-06, -2.2165477e-07,  5.6094050e-01],
#        [ 4.4703484e-07,  8.7544322e-08, -5.6091660e-01]], dtype=float32)}

# %% [markdown]
# # Structure Optimization

# %%
import numpy as np
from pymatgen.core import Structure

structure = Structure.from_file('/content/drive/MyDrive/LiCoO2.cif')

print(f"original: {structure.get_space_group_info()}")
# Out:
# original: ('R-3m', 166)

# %%
import pandas as pd
from chgnet.model import StructOptimizer

result = StructOptimizer().relax(structure)

print("Relaxed structure:\n")
print(result["final_structure"])
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu
#       Step     Time          Energy          fmax
# FIRE:    0 08:22:47      -76.321487        0.560950
# FIRE:    1 08:22:48      -76.345566        0.467104
# FIRE:    2 08:22:48      -76.380447        0.342201
# FIRE:    3 08:22:50      -76.400078        0.220714
# FIRE:    4 08:22:51      -76.398758        0.247368
# FIRE:    5 08:22:53      -76.399696        0.235225
# FIRE:    6 08:22:55      -76.401421        0.211466
# FIRE:    7 08:22:56      -76.403625        0.176636
# FIRE:    8 08:22:57      -76.406013        0.147827
# FIRE:    9 08:22:58      -76.408646        0.137030
# FIRE:   10 08:22:59      -76.411415        0.139111
# FIRE:   11 08:22:59      -76.413811        0.157040
# FIRE:   12 08:23:00      -76.415466        0.176249
# FIRE:   13 08:23:01      -76.416817        0.185620
# FIRE:   14 08:23:02      -76.418442        0.181364
# FIRE:   15 08:23:03      -76.420815        0.167775
# FIRE:   16 08:23:04      -76.423973        0.142828
# FIRE:   17 08:23:04      -76.427307        0.110106
# FIRE:   18 08:23:05      -76.429634        0.058846
# Relaxed structure:
#
# Full Formula (Li3 Co3 O6)
# Reduced Formula: LiCoO2
# abc   :   2.834544   2.834544  14.031720
# angles:  90.000000  90.000000 120.000000
# pbc   :       True       True       True
# Sites (12)
#   #  SP            a          b          c      magmom
# ---  ----  ---------  ---------  ---------  ----------
#   0  Li    -0          0         -0         0.00199389
#   1  Li     0.666667   0.333333   0.333333  0.0019936
#   2  Li     0.333333   0.666667   0.666667  0.00199363
#   3  Co     0.333333   0.666667   0.166667  0.0717191
#   4  Co     0         -0          0.5       0.0717227
#   5  Co     0.666667   0.333333   0.833333  0.0717191
#   6  O     -0          0          0.241152  0.00798258
#   7  O      0.666667   0.333333   0.092182  0.00798264
#   8  O      0.666667   0.333333   0.574485  0.00798276
#   9  O      0.333333   0.666667   0.425515  0.00798243
#  10  O      0.333333   0.666667   0.907818  0.0079827
#  11  O      0         -0          0.758848  0.00798249

# %% [markdown]
# # Visualize Relaxation

# %%
# # 查看方法的文档字符串
# help(StructOptimizer().relax)

trajectory = StructOptimizer().relax(structure, fmax=0.05)["trajectory"]
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cpu
#       Step     Time          Energy          fmax
# FIRE:    0 08:36:41      -76.321487        0.560950
# FIRE:    1 08:36:42      -76.345566        0.467104
# FIRE:    2 08:36:42      -76.380447        0.342201
# FIRE:    3 08:36:43      -76.400078        0.220714
# FIRE:    4 08:36:43      -76.398758        0.247368
# FIRE:    5 08:36:44      -76.399696        0.235225
# FIRE:    6 08:36:44      -76.401421        0.211466
# FIRE:    7 08:36:45      -76.403625        0.176636
# FIRE:    8 08:36:45      -76.406013        0.147827
# FIRE:    9 08:36:46      -76.408646        0.137030
# FIRE:   10 08:36:46      -76.411415        0.139111
# FIRE:   11 08:36:47      -76.413811        0.157040
# FIRE:   12 08:36:47      -76.415466        0.176249
# FIRE:   13 08:36:48      -76.416817        0.185620
# FIRE:   14 08:36:49      -76.418442        0.181364
# FIRE:   15 08:36:49      -76.420815        0.167775
# FIRE:   16 08:36:50      -76.423973        0.142828
# FIRE:   17 08:36:50      -76.427307        0.110106
# FIRE:   18 08:36:51      -76.429634        0.058846
# FIRE:   19 08:36:53      -76.430542        0.063025
# FIRE:   20 08:36:55      -76.431061        0.086832
# FIRE:   21 08:36:56      -76.431221        0.078052
# FIRE:   22 08:36:57      -76.431480        0.061320
# FIRE:   23 08:36:58      -76.431732        0.039472

# %%
e_col = "Energy (eV)"
force_col = "Force (eV/Å)"
df_traj = pd.DataFrame(trajectory.energies, columns=[e_col])
df_traj[force_col] = [
    np.linalg.norm(force, axis=1).mean()  # mean of norm of force on each atom
    for force in trajectory.forces
]
df_traj.index.name = "step"

dft_energy = -76.43
print(f"{dft_energy=:.2f} eV ")
# Out:
# dft_energy=-76.43 eV

# %%
pip install crystal_toolkit
# Out:
# Collecting crystal_toolkit
#   Downloading crystal_toolkit-2025.7.31-py3-none-any.whl.metadata (18 kB)
# Collecting crystaltoolkit-extension (from crystal_toolkit)
#   Downloading crystaltoolkit-extension-0.6.0.tar.gz (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 30.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dash-mp-components>=0.4.38 (from crystal_toolkit)
#   Downloading dash_mp_components-0.4.47.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 97.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dash>=2.11.0 (from crystal_toolkit)
#   Downloading dash-3.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting flask-caching (from crystal_toolkit)
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (2.4.6)
# Collecting mp-api (from crystal_toolkit)
#   Downloading mp_api-0.45.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (2.10.1)
# Requirement already satisfied: pymatgen>=2024.10.22 in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (2025.6.14)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (1.6.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (2.1.1)
# Requirement already satisfied: webcolors in /usr/local/lib/python3.12/dist-packages (from crystal_toolkit) (24.11.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (4.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (2.32.4)
# Collecting retrying (from dash>=2.11.0->crystal_toolkit)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from dash>=2.11.0->crystal_toolkit) (75.2.0)
# Requirement already satisfied: bibtexparser>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (1.4.3)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (1.5.2)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (3.10.0)
# Requirement already satisfied: monty>=2025.1.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (2025.3.3)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (3.5)
# Requirement already satisfied: numpy<3,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (2.0.2)
# Requirement already satisfied: orjson<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (3.11.3)
# Requirement already satisfied: palettable>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (3.3.3)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (2.2.2)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (0.18.15)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (1.16.1)
# Requirement already satisfied: spglib>=2.5 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (2.6.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (1.13.3)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pymatgen>=2024.10.22->crystal_toolkit) (3.2.3)
# Collecting jupyterlab==3.*,>=3.0.0rc13 (from crystaltoolkit-extension->crystal_toolkit)
#   Using cached jupyterlab-3.6.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (7.34.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (25.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (6.4.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (5.8.1)
# Collecting jupyterlab-server~=2.19 (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (2.14.0)
# Collecting jupyter-ydoc~=0.2.4 (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached jupyter_ydoc-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting jupyter-server-ydoc~=0.8.0 (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached jupyter_server_ydoc-0.8.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.3.2)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (6.5.7)
# Requirement already satisfied: jinja2>=2.1 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (3.1.6)
# Collecting cachelib>=0.9.0 (from flask-caching->crystal_toolkit)
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from mp-api->crystal_toolkit) (1.1.1)
# Collecting maggma>=0.57.1 (from mp-api->crystal_toolkit)
#   Downloading maggma-0.72.0-py3-none-any.whl.metadata (11 kB)
# Collecting emmet-core>=0.84.3rc6 (from mp-api->crystal_toolkit)
#   Downloading emmet_core-0.84.10rc2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.12/dist-packages (from mp-api->crystal_toolkit) (7.3.0.post1)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->crystal_toolkit) (2.11.7)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->crystal_toolkit) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings->crystal_toolkit) (0.4.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal_toolkit) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal_toolkit) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal_toolkit) (2025.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->crystal_toolkit) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->crystal_toolkit) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from bibtexparser>=1.4.0->pymatgen>=2024.10.22->crystal_toolkit) (3.2.3)
# Collecting pymatgen-io-validation>=0.1.0 (from emmet-core>=0.84.3rc6->mp-api->crystal_toolkit)
#   Downloading pymatgen_io_validation-0.1.1-py3-none-any.whl.metadata (15 kB)
# Collecting pybtex~=0.24 (from emmet-core>=0.84.3rc6->mp-api->crystal_toolkit)
#   Downloading pybtex-0.25.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal_toolkit) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal_toolkit) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal_toolkit) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->crystal_toolkit) (3.0.2)
# Collecting pymongo<4.11,>=4.2.0 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading pymongo-4.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting mongomock>=3.10.0 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading mongomock-4.3.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pydash>=4.1.0 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading pydash-8.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: jsonschema>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from maggma>=0.57.1->mp-api->crystal_toolkit) (4.25.1)
# Collecting jsonlines>=4.0.0 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aioitertools>=0.5.1 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pyzmq>=25.1.1 in /usr/local/lib/python3.12/dist-packages (from maggma>=0.57.1->mp-api->crystal_toolkit) (26.2.1)
# Collecting dnspython>=1.16.0 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting sshtunnel>=0.1.5 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading sshtunnel-0.4.0-py2.py3-none-any.whl.metadata (19 kB)
# Collecting boto3>=1.20.41 (from maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading boto3-1.40.28-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from maggma>=0.57.1->mp-api->crystal_toolkit) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen>=2024.10.22->crystal_toolkit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen>=2024.10.22->crystal_toolkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen>=2024.10.22->crystal_toolkit) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen>=2024.10.22->crystal_toolkit) (1.4.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen>=2024.10.22->crystal_toolkit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen>=2024.10.22->crystal_toolkit) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->dash>=2.11.0->crystal_toolkit) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->pydantic-settings->crystal_toolkit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->pydantic-settings->crystal_toolkit) (2.33.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.11.0->crystal_toolkit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.11.0->crystal_toolkit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.11.0->crystal_toolkit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dash>=2.11.0->crystal_toolkit) (2025.8.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml>=0.17.0->pymatgen>=2024.10.22->crystal_toolkit) (0.2.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->pymatgen>=2024.10.22->crystal_toolkit) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->dash>=2.11.0->crystal_toolkit) (3.23.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open->mp-api->crystal_toolkit) (1.17.3)
# Collecting botocore<1.41.0,>=1.40.28 (from boto3>=1.20.41->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading botocore-1.40.28-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.41->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3>=1.20.41->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines>=4.0.0->maggma>=0.57.1->mp-api->crystal_toolkit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.1.1->maggma>=0.57.1->mp-api->crystal_toolkit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.1.1->maggma>=0.57.1->mp-api->crystal_toolkit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.1.1->maggma>=0.57.1->mp-api->crystal_toolkit) (0.27.1)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (7.4.9)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (5.7.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (4.4.0)
# Collecting jupyter-server-fileid<1,>=0.6.0 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached jupyter_server_fileid-0.9.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting ypy-websocket<0.9.0,>=0.8.2 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached ypy_websocket-0.8.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting y-py<0.7.0,>=0.6.0 (from jupyter-ydoc~=0.2.4->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached y_py-0.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server~=2.19->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Collecting sentinels (from mongomock>=3.10.0->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading sentinels-1.1.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (6.17.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.2.4)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.12/dist-packages (from pybtex~=0.24->emmet-core>=0.84.3rc6->mp-api->crystal_toolkit) (6.0.2)
# Collecting latexcodec>=1.0.4 (from pybtex~=0.24->emmet-core>=0.84.3rc6->mp-api->crystal_toolkit)
#   Downloading latexcodec-3.0.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->maggma>=0.57.1->mp-api->crystal_toolkit) (1.17.0)
# Collecting paramiko>=2.7.2 (from sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting jedi>=0.16 (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.8.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (2.21.2)
# Collecting bcrypt>=3.2 (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.12/dist-packages (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit) (43.0.3)
# Collecting invoke>=2.0 (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading invoke-2.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pynacl>=1.5 (from paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit)
#   Downloading pynacl-1.6.0-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.2.13)
# Collecting aiofiles<23,>=22.1.0 (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached aiofiles-22.1.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting aiosqlite<1,>=0.17.0 (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit)
#   Using cached aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.8.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook<7->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.3->paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit) (1.17.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.7.2->sshtunnel>=0.1.5->maggma>=0.57.1->mp-api->crystal_toolkit) (2.22)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.2.2)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.0rc13->crystaltoolkit-extension->crystal_toolkit) (2.9.0.20250822)
# Downloading crystal_toolkit-2025.7.31-py3-none-any.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 53.5 MB/s eta 0:00:00
# Downloading dash-3.2.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 81.0 MB/s eta 0:00:00
# Using cached jupyterlab-3.6.8-py3-none-any.whl (8.9 MB)
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading mp_api-0.45.8-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.2/101.2 kB 6.2 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading emmet_core-0.84.10rc2-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.5/264.5 kB 18.4 MB/s eta 0:00:00
# Downloading maggma-0.72.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 9.4 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading boto3-1.40.28-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 8.8 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 20.2 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Using cached jupyter_server_ydoc-0.8.0-py3-none-any.whl (11 kB)
# Using cached jupyter_ydoc-0.2.5-py3-none-any.whl (6.2 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading mongomock-4.3.0-py2.py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.2 MB/s eta 0:00:00
# Downloading pybtex-0.25.1-py2.py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 10.2 MB/s eta 0:00:00
# Downloading pydash-8.0.5-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.1/102.1 kB 7.4 MB/s eta 0:00:00
# Downloading pymatgen_io_validation-0.1.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 3.0 MB/s eta 0:00:00
# Downloading pymongo-4.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 49.6 MB/s eta 0:00:00
# Downloading sshtunnel-0.4.0-py2.py3-none-any.whl (24 kB)
# Downloading botocore-1.40.28-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 51.3 MB/s eta 0:00:00
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached json5-0.12.1-py3-none-any.whl (36 kB)
# Using cached jupyter_server_fileid-0.9.3-py3-none-any.whl (16 kB)
# Downloading latexcodec-3.0.1-py3-none-any.whl (18 kB)
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 kB 12.8 MB/s eta 0:00:00
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.9 MB/s eta 0:00:00
# Using cached y_py-0.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Using cached ypy_websocket-0.8.4-py3-none-any.whl (10 kB)
# Downloading sentinels-1.1.1-py3-none-any.whl (3.7 kB)
# Using cached aiofiles-22.1.0-py3-none-any.whl (14 kB)
# Using cached aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 17.6 MB/s eta 0:00:00
# Downloading invoke-2.2.0-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 12.5 MB/s eta 0:00:00
# Downloading pynacl-1.6.0-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 45.5 MB/s eta 0:00:00
# Building wheels for collected packages: dash-mp-components, crystaltoolkit-extension
#   Building wheel for dash-mp-components (setup.py) ... done
#   Created wheel for dash-mp-components: filename=dash_mp_components-0.4.47-py3-none-any.whl size=6438047 sha256=2f2aa314aa393c6a7e696ed405f04096959808c7947a8d6f2980d6d5ec98a468
#   Stored in directory: /root/.cache/pip/wheels/d8/a6/38/e541a2bf545b63c4fa75588649ac91abd8ea5fa7a4a2b1c400
#   Building wheel for crystaltoolkit-extension (pyproject.toml) ... done
#   Created wheel for crystaltoolkit-extension: filename=crystaltoolkit_extension-0.6.0-py3-none-any.whl size=5424231 sha256=44690671559fc2f4524aa20a4cf21fda237ea304f2ba98195d9c5997b027d6f2
#   Stored in directory: /root/.cache/pip/wheels/56/ae/39/7025038ddbd0bf793d18a9e8604138daba4267e90fc91b42a1
# Successfully built dash-mp-components crystaltoolkit-extension
# Installing collected packages: y-py, dash-mp-components, sentinels, retrying, pydash, latexcodec, jupyter-ydoc, jsonlines, json5, jmespath, jedi, invoke, dnspython, cachelib, bcrypt, aiosqlite, aioitertools, aiofiles, ypy-websocket, pynacl, pymongo, pybtex, mongomock, botocore, s3transfer, paramiko, flask-caching, dash, sshtunnel, pymatgen-io-validation, boto3, maggma, emmet-core, mp-api, jupyterlab-server, jupyter-server-fileid, jupyter-server-ydoc, jupyterlab, crystaltoolkit-extension, crystal_toolkit
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 24.1.0
#     Uninstalling aiofiles-24.1.0:
#       Successfully uninstalled aiofiles-24.1.0
# Successfully installed aiofiles-22.1.0 aioitertools-0.12.0 aiosqlite-0.21.0 bcrypt-4.3.0 boto3-1.40.28 botocore-1.40.28 cachelib-0.13.0 crystal_toolkit-2025.7.31 crystaltoolkit-extension-0.6.0 dash-3.2.0 dash-mp-components-0.4.47 dnspython-2.8.0 emmet-core-0.84.10rc2 flask-caching-2.3.1 invoke-2.2.0 jedi-0.19.2 jmespath-1.0.1 json5-0.12.1 jsonlines-4.0.0 jupyter-server-fileid-0.9.3 jupyter-server-ydoc-0.8.0 jupyter-ydoc-0.2.5 jupyterlab-3.6.8 jupyterlab-server-2.27.3 latexcodec-3.0.1 maggma-0.72.0 mongomock-4.3.0 mp-api-0.45.8 paramiko-4.0.0 pybtex-0.25.1 pydash-8.0.5 pymatgen-io-validation-0.1.1 pymongo-4.10.1 pynacl-1.6.0 retrying-1.4.2 s3transfer-0.14.0 sentinels-1.1.1 sshtunnel-0.4.0 y-py-0.6.2 ypy-websocket-0.8.4

# %%
import crystal_toolkit.components as ctc
import plotly.graph_objects as go
from crystal_toolkit.settings import SETTINGS
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
from pymatgen.core import Structure

app = Dash(prevent_initial_callbacks=True, assets_folder=SETTINGS.ASSETS_PATH)

step_size = max(1, len(trajectory) // 20)  # ensure slider has max 20 steps
slider = dcc.Slider(
    id="slider", min=0, max=len(trajectory) - 1, step=step_size, updatemode="drag"
)


def plot_energy_and_forces(
    df: pd.DataFrame, step: int, e_col: str, force_col: str, title: str
) -> go.Figure:
    """Plot energy and forces as a function of relaxation step."""
    fig = go.Figure()
    # energy trace = primary y-axis
    fig.add_trace(go.Scatter(x=df.index, y=df[e_col], mode="lines", name="Energy"))
    # get energy line color
    line_color = fig.data[0].line.color

    # forces trace = secondary y-axis
    fig.add_trace(
        go.Scatter(x=df.index, y=df[force_col], mode="lines", name="Forces", yaxis="y2")
    )

    fig.update_layout(
        template="plotly_white",
        title=title,
        xaxis=dict(title="Relaxation Step"),
        yaxis=dict(title=e_col),
        yaxis2=dict(title=force_col, overlaying="y", side="right"),
        legend=dict(yanchor="top", y=1, xanchor="right", x=1),
    )

    # vertical line at the specified step
    fig.add_vline(x=step, line=dict(dash="dash", width=1))

    # horizontal line for DFT final energy
    anno = dict(text="DFT final energy", yanchor="top")
    fig.add_hline(
        y=dft_energy,
        line=dict(dash="dot", width=1, color=line_color),
        annotation=anno,
    )

    return fig


def make_title(spg_symbol: str, spg_num: int) -> str:
    """Return a title for the figure."""
    href = f"https://materialsproject.org/materials/{mp_id}/"
    return f"<a {href=}>{mp_id}</a> - {spg_symbol} ({spg_num})"

title = 'plot'
graph = dcc.Graph(
    id="fig",
    figure=plot_energy_and_forces(df_traj, 0, e_col, force_col, title),
    style={"maxWidth": "50%"},
)

struct_comp = ctc.StructureMoleculeComponent(id="structure", struct_or_mol=structure)

app.layout = html.Div(
    [
        html.H1(
            "Structure Relaxation Trajectory", style=dict(margin="1em", fontSize="2em")
        ),
        html.P("Drag slider to see structure at different relaxation steps."),
        slider,
        html.Div([struct_comp.layout(), graph], style=dict(display="flex", gap="2em")),
    ],
    style=dict(margin="auto", textAlign="center", maxWidth="1200px", padding="2em"),
)

ctc.register_crystal_toolkit(app=app, layout=app.layout)


@app.callback(
    Output(struct_comp.id(), "data"), Output(graph, "figure"), Input(slider, "value")
)
def update_structure(step: int) -> tuple[Structure, go.Figure]:
    """Update the structure displayed in the StructureMoleculeComponent and the
    dashed vertical line in the figure when the slider is moved.
    """
    lattice = trajectory.cells[step]
    coords = trajectory.atom_positions[step]
    structure.lattice = lattice  # update structure in place for efficiency
    assert len(structure) == len(coords)
    for site, coord in zip(structure, coords, strict=True):
        site.coords = coord

    title = make_title(*structure.get_space_group_info())
    fig = plot_energy_and_forces(df_traj, step, e_col, force_col, title)

    return structure, fig


app.run(height=800, use_reloader=False)
